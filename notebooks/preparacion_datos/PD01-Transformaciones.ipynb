# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### AP1 - Preparación de los datos
#
# ---
#
# En esta libreta se realizan las transforamciones sobre los datasets del escenario en función
# de los resultados de la verificación de calidad de datos.
#
# ---

# %%
#Se importan las librerias a utilizar

import pandas as pd

# %% [markdown]
# ----
#
# ##### Lectura de los datasets

# %%
df_creditos = pd.read_csv("../../data/processed/datos_creditos_mc.csv", sep=";")
display(df_creditos.head(1))

df_tarjetas = pd.read_csv("../../data/processed/datos_tarjetas_mc.csv", sep=";")
display(df_tarjetas.head(1))
# Out:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago
# 0         0.59         16.02               1          Y
#     id_cliente  antiguedad_cliente estado_civil estado_cliente  \
# 0  713061558.0                36.0       CASADO         ACTIVO
#
#    gastos_ult_12m genero  limite_credito_tc         nivel_educativo  \
# 0          1088.0      M             4010.0  UNIVERSITARIO_COMPLETO
#
#   nivel_tarjeta  operaciones_ult_12m  personas_a_cargo
# 0          Blue                 24.0               2.0

# %% [markdown]
# ---
# #### Aplicación de transformaciones
#
# **Operaciones a realizar**
#
# 1. Selección de columnas
# 2. Filtrado de filas
# 3. Construcción de atributos
# 4. Integración de datasets
# 5. Formateo definitivo

# %% [markdown]
# ----
#
# Selección de datos

# %%
# Se establece qué columnas se eliminan

col_eliminar_creditos = []
col_eliminar_tarjetas = ['nivel_tarjeta']

# Se ejecuta la operación

df_creditos.drop(col_eliminar_creditos, inplace=True, axis=1)
df_tarjetas.drop(col_eliminar_tarjetas, inplace=True, axis=1)

# %%
print("Vista del dataset de datos de créditos:")
display(df_creditos.head(1))

print("Vista del dataset de datos de tarjetas:")
display(df_tarjetas.head(1))
# Out:
# Vista del dataset de datos de créditos:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago
# 0         0.59         16.02               1          Y
# Vista del dataset de datos de tarjetas:
#     id_cliente  antiguedad_cliente estado_civil estado_cliente  \
# 0  713061558.0                36.0       CASADO         ACTIVO
#
#    gastos_ult_12m genero  limite_credito_tc         nivel_educativo  \
# 0          1088.0      M             4010.0  UNIVERSITARIO_COMPLETO
#
#    operaciones_ult_12m  personas_a_cargo
# 0                 24.0               2.0

# %% [markdown]
# Limpieza de los datos (filtrado a nivel de filas)

# %%
#Se puede definir una función para aplicar los cálculos
def regla_pct_ingresos_credito(row):
    pct_ingreso = row.pct_ingreso
    ingresos = row.ingresos
    
    if pct_ingreso > 0.5 and ingresos <= 20000:
        # Es un error, no cumple la regla definida
        return 'err'
    else:
        return 'ok'


# Se aplica la función para todos los elementos del dataset
regla_pct_ingresos = df_creditos.apply(lambda row: regla_pct_ingresos_credito(row), axis=1).rename("regla_pct_ingresos")

# Se unen los resultados al dataset inicial
df_creditos = pd.concat([df_creditos, regla_pct_ingresos], axis=1)
df_creditos.head(5)
# Out:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
# 1  768805383.0    21                1000                 2
# 2  818770008.0    25                5500                 3
# 3  713982108.0    23               35000                 2
# 4  710821833.0    24               35000                 4
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
# 1                  5.0             PROPIA      9600        EDUCACIÓN
# 2                  1.0           HIPOTECA      9600            SALUD
# 3                  4.0           ALQUILER     65500            SALUD
# 4                  8.0           ALQUILER     54400            SALUD
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago regla_pct_ingresos
# 0         0.59         16.02               1          Y                 ok
# 1         0.10         11.14               0          N                 ok
# 2         0.57         12.87               1          N                err
# 3         0.53         15.23               1          N                 ok
# 4         0.55         14.27               1          Y                 ok

# %%
#Se puede definir una función para aplicar los cálculos
def regla_pct_ingresos_credito_min(row):
    duracion_credito = row.duracion_credito
    pct_ingreso = row.pct_ingreso
    situacion_vivienda = row.situacion_vivienda
    
    if duracion_credito==2 and pct_ingreso > 0.6 and situacion_vivienda != "PROPIA":
        # Es un error, no cumple la regla definida
        return 'err'
    else:
        return 'ok'


# Se aplica la función para todos los elementos del dataset
regla_pct_ingresos_min = df_creditos.apply(lambda row: regla_pct_ingresos_credito_min(row), axis=1).rename("regla_pct_ingresos_min")

# Se unen los resultados al dataset inicial
df_creditos = pd.concat([df_creditos, regla_pct_ingresos_min], axis=1)  
df_creditos.head(5)
# Out:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
# 1  768805383.0    21                1000                 2
# 2  818770008.0    25                5500                 3
# 3  713982108.0    23               35000                 2
# 4  710821833.0    24               35000                 4
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
# 1                  5.0             PROPIA      9600        EDUCACIÓN
# 2                  1.0           HIPOTECA      9600            SALUD
# 3                  4.0           ALQUILER     65500            SALUD
# 4                  8.0           ALQUILER     54400            SALUD
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago regla_pct_ingresos  \
# 0         0.59         16.02               1          Y                 ok
# 1         0.10         11.14               0          N                 ok
# 2         0.57         12.87               1          N                err
# 3         0.53         15.23               1          N                 ok
# 4         0.55         14.27               1          Y                 ok
#
#   regla_pct_ingresos_min
# 0                     ok
# 1                     ok
# 2                     ok
# 3                     ok
# 4                     ok

# %%
# Se filtran las filas con algún error detectado
print(f"Filas antes del filtro: {df_creditos.shape[0]}")

temp = df_creditos[df_creditos['edad'] < 90]
temp_a = temp[temp['tasa_interes'] > 0]

# Otro filtro posible: por la regla de negocio agregada

temp_c = temp_a[temp_a['regla_pct_ingresos'] == 'ok']
temp_e = temp_c[temp_c['regla_pct_ingresos_min'] == 'ok']

temp_d = temp_e[temp_e['antiguedad_empleado'] < 50]
temp_f = temp_d[temp_d['antiguedad_empleado']>= 0]

print(f"Filas después del filtro: {temp_f.shape[0]}")
# Out:
# Filas antes del filtro: 10127
# Filas después del filtro: 8878

# %% [markdown]
# Integración de datos

# %%
df_integrado = pd.merge(temp_f, df_tarjetas, on='id_cliente', how='inner')
coincidencias = df_integrado.shape[0]

print(f"Filas del dataset integrado con los filtros realizados: {coincidencias}")
# Out:
# Filas del dataset integrado con los filtros realizados: 8878

# %%
print(f"Cantidad de columnas del dataset integrado: {df_integrado.shape[1]}")
# Out:
# Cantidad de columnas del dataset integrado: 23

# %%
df_integrado.columns
# Out:
# Index(['id_cliente', 'edad', 'importe_solicitado', 'duracion_credito',
#        'antiguedad_empleado', 'situacion_vivienda', 'ingresos',
#        'objetivo_credito', 'pct_ingreso', 'tasa_interes', 'estado_credito',
#        'falta_pago', 'regla_pct_ingresos', 'regla_pct_ingresos_min',
#        'antiguedad_cliente', 'estado_civil', 'estado_cliente',
#        'gastos_ult_12m', 'genero', 'limite_credito_tc', 'nivel_educativo',
#        'operaciones_ult_12m', 'personas_a_cargo'],
#       dtype='object')

# %% [markdown]
# #### Transformación de atributos
#
# Atributos nominales que se modifican los valores

# %%
# Columna: estado_civil
cambios_estado_civil = {
    'CASADO' : 'C',
    'SOLTERO' : 'S',
    'DESCONOCIDO' : 'N',
    'DIVORCIADO' : 'D',
}

estado_civil_N = df_integrado.loc[:, ('estado_civil')].map(cambios_estado_civil).rename('estado_civil_N')

# Columna: estado_credito
cambios_estado_credito = {
    0: 'C',
    1 : 'P',
}

estado_credito_N = df_integrado.loc[:, ('estado_credito')].map(cambios_estado_credito).rename('estado_credito_N')

df_final = pd.concat([estado_civil_N, estado_credito_N, df_integrado], axis=1)
df_final.head()

# Sobre este resultado será necesario eliminar las columnas auxiliares
# Out:
#   estado_civil_N estado_credito_N   id_cliente  edad  importe_solicitado  \
# 0              C                C  768805383.0    21                1000
# 1              C                P  713982108.0    23               35000
# 2              C                P  710821833.0    24               35000
# 3              N                P  769911858.0    21                2500
# 4              C                P  709106358.0    26               35000
#
#    duracion_credito  antiguedad_empleado situacion_vivienda  ingresos  \
# 0                 2                  5.0             PROPIA      9600
# 1                 2                  4.0           ALQUILER     65500
# 2                 4                  8.0           ALQUILER     54400
# 3                 2                  2.0             PROPIA      9900
# 4                 3                  8.0           ALQUILER     77100
#
#   objetivo_credito  ...  regla_pct_ingresos_min  antiguedad_cliente  \
# 0        EDUCACIÓN  ...                      ok                39.0
# 1            SALUD  ...                      ok                36.0
# 2            SALUD  ...                      ok                54.0
# 3      INVERSIONES  ...                      ok                34.0
# 4        EDUCACIÓN  ...                      ok                21.0
#
#    estado_civil estado_cliente gastos_ult_12m genero  limite_credito_tc  \
# 0        CASADO         ACTIVO         1144.0      M            12691.0
# 1        CASADO         ACTIVO         1887.0      M             3418.0
# 2        CASADO         ACTIVO         1314.0      M             9095.0
# 3   DESCONOCIDO         ACTIVO         1171.0      F             3313.0
# 4        CASADO         ACTIVO          816.0      M             4716.0
#
#             nivel_educativo operaciones_ult_12m  personas_a_cargo
# 0       SECUNDARIO_COMPLETO                42.0               3.0
# 1    UNIVERSITARIO_COMPLETO                20.0               3.0
# 2               DESCONOCIDO                26.0               1.0
# 3       SECUNDARIO_COMPLETO                20.0               4.0
# 4  UNIVERSITARIO_INCOMPLETO                28.0               3.0
#
# [5 rows x 25 columns]

# %% [markdown]
# Atributos numéricos que se discretizan

# %%
df_integrado['operaciones_ult_12m'].describe()
# Out:
# count    8878.000000
# mean       65.018135
# std        23.517037
# min        10.000000
# 25%        45.000000
# 50%        67.000000
# 75%        81.000000
# max       139.000000
# Name: operaciones_ult_12m, dtype: float64

# %%
# Antiguedad del empleado

etiquetas_a_e = ['menor_10', '5_a_10', 'mayor_10']
rangos_a_e = [0, 4, 10, 50]
valor_para_nan = 'NA'
antiguedad_empleados_N = pd.cut(df_integrado['antiguedad_empleado'], 
                                bins=rangos_a_e, 
                                labels=etiquetas_a_e,
                                right=False).cat.add_categories(valor_para_nan).fillna(valor_para_nan)

antiguedad_empleados_N.value_counts()

# edad

etiquetas_e = ['menor_25', '25_a_30']
rangos_e = [0, 24, 50]
edad_N = pd.cut(df_integrado['edad'], 
                                bins=rangos_e, 
                                labels=etiquetas_e)

edad_N.value_counts()

# pct_ingreso

etiquetas_p_i = ['hasta_20', '20_a_40', '40_a_60', 'mayor_60']
rangos_p_i = [0, 0.19, 0.39, 0.60, 0.99]
pct_ingreso_N = pd.cut(df_integrado['pct_ingreso'], 
                                bins=rangos_p_i, 
                                labels=etiquetas_p_i)

pct_ingreso_N.value_counts()

# ingresos

etiquetas_i = ['hasta_20k', '20k_a_50k', '50k_a_100k', 'mayor_100k']
rangos_i = [0, 19999, 49999, 99999, 999999]
ingresos_N = pd.cut(df_integrado['ingresos'], 
                                bins=rangos_i, 
                                labels=etiquetas_i)

ingresos_N.value_counts()

# tasa_interes

etiquetas_t_i = ['hasta_7p', '7p_a_15p', '15p_a_20p', 'mayor_20p']
rangos_t_i = [0, 6.99, 14.99, 19.99, 100]
tasa_interes_N = pd.cut(df_integrado['tasa_interes'], 
                                bins=rangos_t_i, 
                                labels=etiquetas_t_i)

tasa_interes_N.value_counts()

# antiguedad_cliente

etiquetas_a_c = ['menor_2y', '2y_a_4y', 'mayor_4y']
rangos_a_c = [0, 24, 48, 100]
antiguedad_cliente_N = pd.cut(df_integrado['antiguedad_cliente'], 
                                bins=rangos_a_c, 
                                labels=etiquetas_a_c)

antiguedad_cliente_N.value_counts()

# limite_credito_tc

etiquetas_l_tc = ['menor_3k', '3k_a_5k', '5k_a_10k', 'mayor_10k']
rangos_l_tc = [0, 2999, 4999, 9999, 100000]
limite_credito_tc_N = pd.cut(df_integrado['limite_credito_tc'], 
                                bins=rangos_l_tc, 
                                labels=etiquetas_l_tc)

limite_credito_tc_N.value_counts()

# gastos_ult_12m

etiquetas_g_u12 = ['menor_1k', '2k_a_4k', '4k_a_6k', '6k_a_8k', '8k_a_10k', 'mayor_10k']
rangos_g_u12 = [0, 999, 3999, 5999, 7999, 9999, 100000]
gastos_ult_12m_N = pd.cut(df_integrado['gastos_ult_12m'], 
                                bins=rangos_g_u12, 
                                labels=etiquetas_g_u12)

gastos_ult_12m_N.value_counts()

# operaciones_ult_12m

etiquetas_o_u12 = ['menor_15', '15_a_30', '30_a_50', '50_a_75', '75_a_100', 'mayor_100']
rangos_o_u12 = [0, 14, 29, 49, 74, 99, 1000]
operaciones_ult_12m_N = pd.cut(df_integrado['operaciones_ult_12m'], 
                                bins=rangos_o_u12, 
                                labels=etiquetas_o_u12)

operaciones_ult_12m_N.value_counts()
# Out:
# operaciones_ult_12m
# 50_a_75      2984
# 75_a_100     2653
# 30_a_50      2091
# mayor_100     608
# 15_a_30       520
# menor_15       22
# Name: count, dtype: int64

# %%
col_eliminar_final = [
              'edad',
              'estado_credito',
              'estado_civil',
              'antiguedad_empleado',
              'antiguedad_cliente', 
              'ingresos',
              'pct_ingreso', 
              'tasa_interes',
              'gastos_ult_12m', 
              'limite_credito_tc', 
              'operaciones_ult_12m',
              'id_cliente']

df_integrado.drop(col_eliminar_final, inplace=True, axis=1)


df_final = pd.concat([estado_civil_N, estado_credito_N, operaciones_ult_12m_N, gastos_ult_12m_N, limite_credito_tc_N, antiguedad_cliente_N, tasa_interes_N, ingresos_N, pct_ingreso_N, antiguedad_empleados_N, edad_N, df_integrado], axis=1)
df_final.head(5)
# Out:
#   estado_civil_N estado_credito_N operaciones_ult_12m gastos_ult_12m  \
# 0              C                C             30_a_50        2k_a_4k
# 1              C                P             15_a_30        2k_a_4k
# 2              C                P             15_a_30        2k_a_4k
# 3              N                P             15_a_30        2k_a_4k
# 4              C                P             15_a_30       menor_1k
#
#   limite_credito_tc antiguedad_cliente tasa_interes    ingresos pct_ingreso  \
# 0         mayor_10k            2y_a_4y     7p_a_15p   hasta_20k    hasta_20
# 1           3k_a_5k            2y_a_4y    15p_a_20p  50k_a_100k     40_a_60
# 2          5k_a_10k           mayor_4y     7p_a_15p  50k_a_100k     40_a_60
# 3           3k_a_5k            2y_a_4y     7p_a_15p   hasta_20k     20_a_40
# 4           3k_a_5k           menor_2y     7p_a_15p  50k_a_100k     40_a_60
#
#   antiguedad_empleado  ... duracion_credito  situacion_vivienda  \
# 0              5_a_10  ...                2              PROPIA
# 1              5_a_10  ...                2            ALQUILER
# 2              5_a_10  ...                4            ALQUILER
# 3            menor_10  ...                2              PROPIA
# 4              5_a_10  ...                3            ALQUILER
#
#    objetivo_credito falta_pago regla_pct_ingresos regla_pct_ingresos_min  \
# 0         EDUCACIÓN          N                 ok                     ok
# 1             SALUD          N                 ok                     ok
# 2             SALUD          Y                 ok                     ok
# 3       INVERSIONES          N                 ok                     ok
# 4         EDUCACIÓN          N                 ok                     ok
#
#   estado_cliente genero           nivel_educativo personas_a_cargo
# 0         ACTIVO      M       SECUNDARIO_COMPLETO              3.0
# 1         ACTIVO      M    UNIVERSITARIO_COMPLETO              3.0
# 2         ACTIVO      M               DESCONOCIDO              1.0
# 3         ACTIVO      F       SECUNDARIO_COMPLETO              4.0
# 4         ACTIVO      M  UNIVERSITARIO_INCOMPLETO              3.0
#
# [5 rows x 22 columns]

# %%
df_final.columns
# Out:
# Index(['estado_civil_N', 'estado_credito_N', 'operaciones_ult_12m',
#        'gastos_ult_12m', 'limite_credito_tc', 'antiguedad_cliente',
#        'tasa_interes', 'ingresos', 'pct_ingreso', 'antiguedad_empleado',
#        'edad', 'importe_solicitado', 'duracion_credito', 'situacion_vivienda',
#        'objetivo_credito', 'falta_pago', 'regla_pct_ingresos',
#        'regla_pct_ingresos_min', 'estado_cliente', 'genero', 'nivel_educativo',
#        'personas_a_cargo'],
#       dtype='object')

# %%
df_final.shape[0]
# Out:
# 8878

# %%
df_final.shape[1]
# Out:
# 22

# %% [markdown]
# Exportación de metadatos

# %%
import dtale as dt

informe = dt.show(df_final)
informe.open_browser()
# Out:
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# 2024-07-13 18:17:44,476 - ERROR    - Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\views.py", line 120, in _handle_exceptions
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\views.py", line 3154, in get_column_analysis
#     return jsonify(**analysis.build())
#                      ^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 457, in build
#     hist = self.build_hist(s, code)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 511, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#                     ^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\generic.py", line 6299, in __getattr__
#     return object.__getattribute__(self, name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\accessor.py", line 224, in __get__
#     accessor_obj = self._accessor(obj)
#                    ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\strings\accessor.py", line 191, in __init__
#     self._inferred_dtype = self._validate(data)
#                            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\strings\accessor.py", line 245, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# 2024-07-13 18:33:16,982 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\views.py", line 120, in _handle_exceptions
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\views.py", line 3154, in get_column_analysis
#     return jsonify(**analysis.build())
#                      ^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 185, in build
#     return_data, hist_labels = self.build_histogram_data(
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 161, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\numpy\lib\histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\numpy\lib\histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\numpy\lib\histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#             ^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\pandas_util.py:19: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\pandas_util.py:19: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# 2024-07-13 19:04:46,006 - ERROR    - Exception occurred while processing request: agg function failed [how->mean,dtype->object]
# Traceback (most recent call last):
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\groupby.py", line 1942, in _agg_py_fallback
#     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\ops.py", line 864, in agg_series
#     result = self._aggregate_series_pure_python(obj, func)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\ops.py", line 885, in _aggregate_series_pure_python
#     res = func(group)
#           ^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\groupby.py", line 2454, in <lambda>
#     alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\series.py", line 6549, in mean
#     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\generic.py", line 12420, in mean
#     return self._stat_function(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\generic.py", line 12377, in _stat_function
#     return self._reduce(
#            ^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\series.py", line 6457, in _reduce
#     return op(delegate, skipna=skipna, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\nanops.py", line 147, in f
#     result = alt(values, axis=axis, skipna=skipna, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\nanops.py", line 404, in new_func
#     result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\nanops.py", line 720, in nanmean
#     the_sum = _ensure_numeric(the_sum)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\nanops.py", line 1701, in _ensure_numeric
#     raise TypeError(f"Could not convert string '{x}' to numeric")
# TypeError: Could not convert string '...' to numeric
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\views.py", line 120, in _handle_exceptions
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\views.py", line 3154, in get_column_analysis
#     return jsonify(**analysis.build())
#                      ^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py", line 326, in build
#     ].agg(self.aggs)
#       ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\generic.py", line 1432, in aggregate
#     result = op.agg()
#              ^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\apply.py", line 193, in agg
#     return self.agg_list_like()
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\apply.py", line 326, in agg_list_like
#     return self.agg_or_apply_list_like(op_name="agg")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\apply.py", line 1571, in agg_or_apply_list_like
#     keys, results = self.compute_list_like(op_name, selected_obj, kwargs)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\apply.py", line 385, in compute_list_like
#     new_res = getattr(colg, op_name)(func, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\generic.py", line 257, in aggregate
#     ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\generic.py", line 362, in _aggregate_multiple_funcs
#     results[key] = self.aggregate(func, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\generic.py", line 249, in aggregate
#     return getattr(self, func)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\groupby.py", line 2452, in mean
#     result = self._cython_agg_general(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\groupby.py", line 1998, in _cython_agg_general
#     new_mgr = data.grouped_reduce(array_func)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\internals\base.py", line 367, in grouped_reduce
#     res = func(arr)
#           ^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\groupby.py", line 1995, in array_func
#     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\pandas\core\groupby\groupby.py", line 1946, in _agg_py_fallback
#     raise type(err)(msg) from err
# TypeError: agg function failed [how->mean,dtype->object]
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Users\USUARIO\Desktop\VIU\Metodologias\AP1\13MBID_EVEMORALES\.venv\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# 2024-07-13 20:04:48,339 - INFO     - Executing shutdown due to inactivity...
# 2024-07-13 20:05:00,632 - INFO     - Executing shutdown...
# 2024-07-13 20:05:00,636 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %% [markdown]
# Exportación del dataset

# %%
df_final.to_csv("../../data/final/datos_finales.csv", sep=';', index=False)
